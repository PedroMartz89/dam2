# %%
import pandas as pd
import numpy as np
myvector1 = np.array([1,2,3,4,5])
print("myvector1:")
print(myvector1)
print()
mydf1 = pd.DataFrame(myvector1)
print("mydf1:")
print(mydf1)
print()
myvector2 = np.array([i for i in range(1,6)])
print("myvector2:")
print(myvector2)
print()
mydf2 = pd.DataFrame(myvector2)
print("mydf2:")
print(mydf2)
print()
myarray = np.array([[10,30,20], [50,40,60],[1000,2000,3000]])
print("myarray:")
print(myarray)
print()
mydf3 = pd.DataFrame(myarray)
print("mydf3:")
print(mydf3)
print()
# Out:
# myvector1:
# [1 2 3 4 5]
#
# mydf1:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
#
# myvector2:
# [1 2 3 4 5]
#
# mydf2:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
#
# myarray:
# [[  10   30   20]
#  [  50   40   60]
#  [1000 2000 3000]]
#
# mydf3:
#       0     1     2
# 0    10    30    20
# 1    50    40    60
# 2  1000  2000  3000

# %% [markdown]
# En los elementos anteriores, se aprecia que los dataframes de pandas ponen claves de filas y columnas por defecto, que serán números si no damos otro tipo de claves. Vamos a crear un df ahora en forma de diccionario:

# %%
names = pd.Series(['SF', 'San Jose', 'Sacramento'])
sizes = pd.Series([852469, 1015785, 485199])
df = pd.DataFrame({ 'Ciudades': names, 'Tamaño': sizes })
print(df)
print("primera ciudad: ")
print(df['Ciudades'][0])
print("tamaño de la ciudad: ")
print(df['Tamaño'][0])
# Out:
#      Ciudades   Tamaño
# 0          SF   852469
# 1    San Jose  1015785
# 2  Sacramento   485199
# primera ciudad:
# SF
# tamaño de la ciudad:
# 852469

# %% [markdown]
# EJERCICIO:\
# 1.- Mostrar el nombre de la segunda ciudad\
# 2.- Mostrar el tamaño de San Franciso

# %%
import pandas as pd

#Ejercicio 1
names = pd.Series(['SF', 'San Jose', 'Sacramento'])
sizes = pd.Series([852469, 1015785, 485199])
df = pd.DataFrame({ 'Ciudades': names, 'Tamaño': sizes })
print("Segunda ciudad: ", df['Ciudades'][1])

#Ejercicio 2
print("Tamaño de San Francisco: ", df['Tamaño'][0] )
# Out:
# Segunda ciudad:  San Jose
# Tamaño de San Francisco:  852469

# %%
myarray = np.array([[10,30,20],
[50,40,60],[1000,2000,3000]])
filas = ['manzanas', 'naranjas', 'bebida']
columnas = ['Enero', 'Febrero', 'Marzo']
mydf = pd.DataFrame(myarray, index=filas, columns=columnas)
print("contenido del dataframe:")
print(mydf)
print()
print("contents of Enero:")
print(mydf['Enero'])
print()
print("Number of filas:")
print(mydf.shape[0])
print()
print("Number of Columnas:")
print(mydf.shape[1])
print()
print("Number of Filas y columnas:")
print(mydf.shape)
print()
print("Nombre de las columnas:")
print(mydf.columns)
print()
print("Tipos de las columnas:")
print(mydf.dtypes)
print()
print("Descripción:")
print(mydf.describe())
# Out:
# contenido del dataframe:
#           Enero  Febrero  Marzo
# manzanas     10       30     20
# naranjas     50       40     60
# bebida     1000     2000   3000
#
# contents of Enero:
# manzanas      10
# naranjas      50
# bebida      1000
# Name: Enero, dtype: int64
#
# Number of filas:
# 3
#
# Number of Columnas:
# 3
#
# Number of Filas y columnas:
# (3, 3)
#
# Nombre de las columnas:
# Index(['Enero', 'Febrero', 'Marzo'], dtype='object')
#
# Tipos de las columnas:
# Enero      int64
# Febrero    int64
# Marzo      int64
# dtype: object
#
# Descripción:
#              Enero      Febrero        Marzo
# count     3.000000     3.000000     3.000000
# mean    353.333333   690.000000  1026.666667
# std     560.386771  1134.504297  1709.073823
# min      10.000000    30.000000    20.000000
# 25%      30.000000    35.000000    40.000000
# 50%      50.000000    40.000000    60.000000
# 75%     525.000000  1020.000000  1530.000000
# max    1000.000000  2000.000000  3000.000000

# %%
mydf.plot()
# Out:
# <Axes: >

# %% [markdown]
# Trasponer un dataframe

# %%
df1 = pd.DataFrame({'a': [1, 0, 1], 'b': [0, 1, 1] },
dtype=int)
print(df1)
print("df1.T:")
print(df1.T)
# Out:
#    a  b
# 0  1  0
# 1  0  1
# 2  1  1
# df1.T:
#    0  1  2
# a  1  0  1
# b  0  1  1

# %% [markdown]
# EJERCICIO\
# 3. Transponer el dataframe de mydf

# %%
#Ejercicio 3
import numpy as np
import pandas as pd
myarray = np.array([[10,30,20],
[50,40,60],[1000,2000,3000]])
filas = ['manzanas', 'naranjas', 'bebida']
columnas = ['Enero', 'Febrero', 'Marzo']
mydf = pd.DataFrame(myarray, index=filas, columns=columnas)
print("mydf Transpuesto: ")
print(mydf.T)
dfT = mydf.T
dfT.plot()
# Out:
# mydf Transpuesto:
#          manzanas  naranjas  bebida
# Enero          10        50    1000
# Febrero        30        40    2000
# Marzo          20        60    3000
# <Axes: >

# %%
df = mydf.T
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# Suma de dataframes

# %%
df1 = pd.DataFrame({'a' : [1, 0, 1], 'b' : [0, 1, 1] },
dtype=int)
df2 = pd.DataFrame({'a' : [3, 3, 3], 'b' : [5, 5, 5] },
dtype=int)
print("df1 + df2:")
print(df1 + df2)
# Out:
# df1 + df2:
#    a  b
# 0  4  5
# 1  3  6
# 2  4  6

# %% [markdown]
# Dataframe con contenido aleatorio

# %%
df = pd.DataFrame(np.random.randint(1, 5, size=(5, 2)),
columns=['a','b'])
dfr = pd.concat([df, df.agg(['sum', 'mean'])])
print("Contenido del dataframe:")
print(dfr)
# Out:
# Contents of dataframe:
#          a    b
# 0      1.0  1.0
# 1      3.0  2.0
# 2      4.0  1.0
# 3      4.0  3.0
# 4      3.0  2.0
# sum   15.0  9.0
# mean   3.0  1.8

# %% [markdown]
# EJERCICIO\
# 4.- Crea un nuevo datframe llamado df4 que contenga número aleatorios entre el 2 y el 8, con 3 filas y 3 columnas donde las columnas se llamen DAM, DAW y ASIR.
# \
# 5.- Muestra el contenido del dataframe df4.\

# %%
#Ejercicio 4
df4 = pd.DataFrame(np.random.randint(2, 8, size=(3,3)), columns=['DAM', 'DAW', 'ASIR'])
#Ejercicio 5
print(df4)
# Out:
#    DAM  DAW  ASIR
# 0    5    3     5
# 1    7    7     2
# 2    7    2     5

# %%
dfc = pd.concat([df, df[['Cost', 'Revenue', 'Total']].agg(['sum', 'mean'], axis=1)], axis=1)
print("Contenido del dataframe:")
print(dfc)
# Out:
# Contents of dataframe:
#   Quarter   Cost  Revenue  Total      sum          mean
# 0      Q1 -23500    40000  16500  33000.0  11000.000000
# 1      Q2 -34000    40000   6000  12000.0   4000.000000
# 2      Q3 -57000    40000 -17000 -34000.0 -11333.333333
# 3      Q4 -32000    40000   8000  16000.0   5333.333333

# %%
df = pd.DataFrame({'data1' : np.random.randn(5),
'data2' : np.random.randn(5)})
print("contents of data1:")
print(df.data1)
print("contents of data2:")
print(df.data2)
print("contents of df:")
print(df)
# Out:
# contents of data1:
# 0    0.833269
# 1   -0.002864
# 2   -0.830080
# 3    1.008509
# 4   -0.594988
# Name: data1, dtype: float64
# contents of data2:
# 0    0.949484
# 1    1.239623
# 2   -0.433856
# 3    2.149521
# 4   -1.675820
# Name: data2, dtype: float64
# contents of df:
#       data1     data2
# 0  0.833269  0.949484
# 1 -0.002864  1.239623
# 2 -0.830080 -0.433856
# 3  1.008509  2.149521
# 4 -0.594988 -1.675820

# %% [markdown]
# Combinar dataframes con concat

# %%
import pandas as pd
can_weather = pd.DataFrame({
"city": ["Vancouver","Toronto","Montreal"],
"temperature": [72,65,50],
"humidity": [40, 20, 25]
})
us_weather = pd.DataFrame({
"city": ["SF","Chicago","LA"],
"temperature": [60,40,85],
"humidity": [30, 15, 55]
})
df = pd.concat([can_weather, us_weather])
print(df)
# Out:
#         city  temperature  humidity
# 0  Vancouver           72        40
# 1    Toronto           65        20
# 2   Montreal           50        25
# 0         SF           60        30
# 1    Chicago           40        15
# 2         LA           85        55

# %% [markdown]
# Seleccionar, añadir y borrar columnas

# %%
df = pd.DataFrame.from_dict({'A':[1,2,3],'B':[4,5,6]},
orient='index', columns=['one', 'two', 'three'])
print(df)
# Out:
#    one  two  three
# A    1    2      3
# B    4    5      6

# %%
df['four'] = df['one'] * df['two']
print(df)
# Out:
#    one  two  three  four
# A    1    2      3     2
# B    4    5      6    20

# %%
df['three'] = df['two'] * df['two']
print(df)
# Out:
#    one  two  three  four
# A    1    2      4     2
# B    4    5     25    20

# %%
import numpy as np
rand = np.random.randn(2)
df.insert(1, 'random', rand)
print(df)
# Out:
#    one    random  two  three  four
# A    1  0.470911    2      4     2
# B    4 -0.919851    5     25    20

# %%
df['flag'] = df['one'] > 2
print(df)
# Out:
#    one    random  two  three  four   flag
# A    1  0.470911    2      4     2  False
# B    4 -0.919851    5     25    20   True

# %%
del df['two']
print(df)
# Out:
#    one    random  three  four   flag
# A    1  0.470911      4     2  False
# B    4 -0.919851     25    20   True

# %%
three = df.pop('three')
print(df)
# Out:
#    one    random  four   flag
# A    1  0.470911     2  False
# B    4 -0.919851    20   True

# %%
df['foo'] = 'bar'
print(df)
# Out:
#    one    random  four   flag  foo
# A    1  0.470911     2  False  bar
# B    4 -0.919851    20   True  bar

# %% [markdown]
# Desviaciones y anomalías

# %%
import pandas as pd
from scipy import stats
from sklearn import datasets

df = datasets.load_iris()
columns = df.feature_names
iris_df = pd.DataFrame(df.data)
iris_df.columns = columns

print("=> iris_df.shape:",iris_df.shape)
print(iris_df.head())
print()

z = np.abs(stats.zscore(iris_df))
print("z scores for iris:")
print("z.shape:",z.shape)

upper = 2.5
lower = 0.01
print("=> upper outliers:")
print(z[np.where(z > upper)])
print(iris_df[z > upper])
print()

outliers = iris_df[z < lower]
print("=> lower outliers:")
print(outliers)
print()
# Out:
# => iris_df.shape: (150, 4)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# z scores for iris:
# z.shape: (150, 4)
# => upper outliers:
# [3.09077525 2.63038172]
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 15                5.7               4.4                1.5               0.4
# 33                5.5               4.2                1.4               0.2
#
# => lower outliers:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# ...

# %% [markdown]
# Scatterplots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from pandas import read_csv
from pandas.plotting import scatter_matrix
myarray = np.array([[10,30,20],
[50,40,60],[1000,2000,3000]])
rownames = ['apples', 'oranges', 'beer']
colnames = ['January', 'February', 'March']
mydf = pd.DataFrame(myarray, index=rownames, columns=colnames)
print(mydf)
print(mydf.describe())
scatter_matrix(mydf)
plt.show()
# Out:
#          January  February  March
# apples        10        30     20
# oranges       50        40     60
# beer        1000      2000   3000
#            January     February        March
# count     3.000000     3.000000     3.000000
# mean    353.333333   690.000000  1026.666667
# std     560.386771  1134.504297  1709.073823
# min      10.000000    30.000000    20.000000
# 25%      30.000000    35.000000    40.000000
# 50%      50.000000    40.000000    60.000000
# 75%     525.000000  1020.000000  1530.000000
# max    1000.000000  2000.000000  3000.000000

# %% [markdown]
# EJERCICIOS\
# 6. Crea un DataFrame (dfimportes) con los datos de la tabla siguiente:\
# Mes	Ventas	Gastos\
# Enero	30500	22000\
# Febrero	35600	23400\
# Marzo	28300	18100\
# Abril	33900	20700
#
#
# 7. Partiendo del DataFrame del ejercicio anterior, añade una columna llamada Balance, que devuelva el balance (ventas - gastos).
#
# 8.Crea un nuevo dataframe (dfnotas) que contenga el nombre de 10 alumnos y sus notas de la primera evaluación en 3 módulos (sostenibilidad, ia y SGE) y devuelva una serie con la nota mínima, la máxima, media y la desviación típica.
#
# 9. Dado el dataframe anterior devuelve una serie con las notas de los alumnos aprobados ordenadas de mayor a menor. (2 puntos)

# %%
#Ejercicio 6
dfimportes =
