# %% [markdown]
# 1. Tipos de Datos y Variables
# Python es un lenguaje de tipado dinámico, lo que significa que no necesitas declarar si una variable es un número o un texto; el intérprete lo deduce.

# %%
# Variables numéricas
edad = 25          # Entero (int)
precio = 19.99     # Flotante (float)

# Cadenas de texto
nombre = "Python"  # String (str)

# Booleanos (Lógica)
es_divertido = True # Booleano (bool)

print(f"Me llamo {nombre} y tengo {edad} años.")
# Out:
# Me llamo Python y tengo 25 años.

# %% [markdown]
# 2. Operadores Aritméticos
# Además de los básicos, Python incluye operadores útiles para algoritmos.

# %%
a, b = 13, 4

print("Suma:", a + b)
print("División Real:", a / b)   # Devuelve decimales (3.25)
print("División Entera:", a // b) # Descarta decimales (3)
print("Módulo (Resto):", a % b)   # Útil para saber si un número es par (a % 2 == 0)
print("Potencia:", a ** 2)        # 13 al cuadrado
# Out:
# Suma: 17
# División Real: 3.25
# División Entera: 3
# Módulo (Resto): 1
# Potencia: 169

# %% [markdown]
# 3. Condicionales (Toma de decisiones)
#
# La clave en Python es la indentación (el sangrado). Todo lo que esté "dentro" del if debe llevar 4 espacios.

# %%
nota = 8.5

if nota >= 9:
    print("Excelente")
elif nota >= 5:
    print("Aprobado")
else:
    print("Suspenso")
# Out:
# Aprobado

# %% [markdown]
# 4. Estructuras de Datos: Listas, Tuplas y Diccionarios

# %%
# --- LISTA: Ordenada y se puede modificar (MUTABLE) ---
alumnos = ["Ana", "Luis"]
alumnos.append("Marta") # Añadir al final
alumnos[0] = "Adriana"  # Modificar el primer elemento

# --- TUPLA: Ordenada pero NO se puede modificar (INMUTABLE) ---
# Se usa para datos que deben ser constantes o protegidos.
coordenadas = (40.41, -3.70)

# --- DICCIONARIO: Colección de par Clave: Valor ---
usuario = {"id": 1, "username": "python_user"}

print(f"Lista: {alumnos}")
print(f"Tupla: {coordenadas}")
print(f"Nombre de usuario: {usuario['username']}")
# Out:
# Lista: ['Adriana', 'Luis', 'Marta']
# Tupla: (40.41, -3.7)
# Nombre de usuario: python_user

# %% [markdown]
# 5. Bucles (Iteraciones)
#
# El bucle for en Python es muy potente para recorrer colecciones directamente.

# %%
# Recorrer una lista
print("Lista de alumnos:")
for alumno in alumnos:
    print(f"- {alumno}")

# Bucle con rango (range)
print("\nContando del 0 al 2:")
for i in range(3):
    print(i)
# Out:
# Lista de alumnos:
# - Adriana
# - Luis
# - Marta
#
# Contando del 0 al 2:
# 0
# 1
# 2

# %% [markdown]
# 6. Cadenas de Texto (Strings) 🔤
#
# Las cadenas son secuencias de caracteres inmutables. Esto significa que no puedes cambiar una letra directamente (ej: nombre[0] = 'A' dará error), debes crear una nueva cadena.

# %%
# Métodos de las cadenas
mensaje = "  aprender python es divertido  "

# Formatear el texto
print(f"Original: '{mensaje}'")
# Covertir en mayúsculas
print(f"Mayúsculas: {mensaje.upper()}")
# Elimina los espacios en blanco laterales
print(f"Sin espacios laterales: '{mensaje.strip()}'")
# Busca una subcadena (parámetro 1) y la remplaza (parámetro 2)
print(f"Reemplazar: {mensaje.replace('divertido', 'genial')}")

# Dividir la cadena en una lista
palabras = mensaje.split()
print(f"Lista de palabras: {palabras}")
# Out:
# Original: '  aprender python es divertido  '
# Mayúsculas:   APRENDER PYTHON ES DIVERTIDO
# Sin espacios laterales: 'aprender python es divertido'
# Reemplazar:   aprender python es genial
# Lista de palabras: ['aprender', 'python', 'es', 'divertido']

# %% [markdown]
# **Iteración sobre Cadenas**
#
# Podemos recorrer cada carácter utilizando un bucle for.

# %%
palabra = "Python"
print("Iterando sobre la palabra:")
for letra in palabra:
    print(f"Letra actual: {letra}")
# Out:
# Iterando sobre la palabra:
# Letra actual: P
# Letra actual: y
# Letra actual: t
# Letra actual: h
# Letra actual: o
# Letra actual: n

# %% [markdown]
# 7. Funciones
#
# Las funciones permiten encapsular lógica para no repetir código.

# %%
def calcular_area(base, altura):
    """Calcula el área de un rectángulo."""
    return base * altura

# Llamada a la función
resultado = calcular_area(10, 5)
print(f"El área calculada es: {resultado}")
# Out:
# El área calculada es: 50
